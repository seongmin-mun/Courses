# %% [markdown]
# # Practice: Analyzing Polysemy and Semantic Change Using COHA Corpus
# <br>
#
# <a href="https://colab.research.google.com/github/seongmin-mun/Courses/blob/master/2024/CorpusLinguistics/Polysemy and Semantic Change/code/Code_Polysemy and Semantic Change.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# <br>
# ## Overview
# This practical session demonstrates how to analyze the polysemy of the word "mouse" over time using COHA (Corpus of Historical American English) data. Specifically, we will explore:
#
# 1. **Morphological Analysis**: Breaking sentences into morphemes and extracting meaningful context words.
# 2. **Window Collocations**: Calculating co-occurrence frequencies within a defined context window.
# 3. **Collocation Measures**: Using statistical metrics—Expected Frequency, MI, LL, Z-Score, and T-Score—to evaluate collocates.
# 4. **Semantic Change Detection**: Demonstrating the shift in the meaning of "mouse" from "animal" to "computer device" between the 1850s and 2000s.

# %% [markdown]
# ## Step 1: Data Preparation
# **Objective**: Ensure COHA data for the 1850s and 2000s is available and preprocess the data by splitting sentences into morphemes and filtering for content words.

# %%
# fileDir = "../data/coha_1850s.txt"
fileDir = "../data/coha_2000s.txt"
fr = open(fileDir, 'r', encoding='utf-8')
contents = fr.readlines()
fr.close()

textList = []
AllWordsList = []

num = 0
for content in contents:
    content = content.replace("\n", "")
    if num < 100:
        print(content)
    textList.append(content.lower())
    
    words = content.lower().strip().split(" ")
    for word in words:
        AllWordsList.append(word)
    num += 1
# Out:
# Sentence
# 13048 time late 1840 s the low down riverfront side of new orleans
# a pretty black eyed olive skin white woman about 30 dressed as an africamerican slave performs menial household and yard tasks
# her clothing is period urban slave
# in a genuine mississippi delta style she variously sings hums hollers slurs a traditional slow tempo africamerican spiritual how long watchman how long
# her singing matches her work pace
# it is throaty lusty fervent but remains an accompaniment to the performance of her chores
# she speaks and sings in a genuine black dialect
# for a moment she stops singing as she silently remembers something and moves to a musical sound in her head something german a popular dance song circa 1818 perhaps some joyous music from a long ago wedding reception now a dim scarce trace of a memory that periodically careens through the unconcious like a comet and possesses her soul
# the comet disappears shift to indicate an internal moment a soliloquy
# the following is actually a call and answer songchant
# salome call i ask my father how long answer how long watchman how long call wellllll he do nt know how long answer how long watchman how long i ask my mother how long how long watchman how long ooooooh she do nt know how long how long watchman how long i ask my neighbor how long how long watchman how long welllll he do nt know how long how long watchman how long i ask de masta how long how long watchman how long annnnnd he do nt know how long i ask da missy how long how long watchman how long lawwwwwd she do nt know how long how long watchman how long i ask da preacha how long how long preacha how long ooooooh he do nt know how long how long preacha needed can be added but mind the order of them and what they are saying
# p
# 3 salome missy wo nt whup me taday
# no sah
# not taday
# ah gits ebeyting done
# i clean de tavern an ah haul in de liquor fore de customers commence ta comin and drinkin an carryin on
# den ah goes down ta de house an make de beds wash de clothes dry de clothes cook de food hoe de weeds in da garden shuck de corn feed de dogs an de chickens collec de eggs
#
#
# lawd hamercy ise tired but jesus will see me through
# sings a moment jesus loves me this is i know for the bible tells me so resumes speaking jesus gim me da strenf
# yes lawd
# ah counts my blessin s
# got a good massa
# heah what ise tellin ya
# massa belmonti a good man
# but his missy lawd fidden ta speak ta her
# reckon da lawd know what he doin
# he mista terious do nt know what da lawd thinkin
# yessah ise proud ta be massa s mary
# ah tells folks i belongs ta massa belmonti they treats me good
# got plenty feed
# good warm shanty with blankets and a fireplace
# get suga and molassas
# plenty fatback
# cornmeal
# chicken on sunday
# good leavin s ebey day
# he a good man massa belmonti
# he do nt low missy lay dat stick on mah back
# massa like me plenty
# yessah massa like me plenty
# he tell me so when he come at night
# brang me a lil gift
# touch my face
# bitter jealously fear dat missy ob his mek ya wuck till ya bones gits soft an den complain bout what you ai nt done
# she beat ya till ya scream an de blood run warm down ya legs
# she da devil
# spida bitch
# may she bun up in hellfire
# she spiteful tawad my two chilrens my two boys
# ole dried up white bitch cai nt ha no chilrens
# her birthin hole stopped up with hate and spite
# da lawd seen fit ta keep chilren s out her hands
# she be done roll over her chilrens and smotha dem lak in da bible an den wan na cut em in half or some such
# dat bitch need ta go back ta hell where she come fum
# fornicate wit satan
# work me till mah hands bleed an mah tongue hang out
# but massa like me
# dem massa s boys
# mah chilrens
# dem massa s boys
# dat bitch cai nt git roun dat
# nossah
# shut her mouth wide open
# bitch cai nt beat me no mo
# massa bless his heart do nt low dat
# ise a sho nuff woman not a bitch fum hell
# dis slave woman got mo lady in long watchman how long welllllll he do nt know how long karla enters white about 30
# she is passing by when she notices the singing slave woman salome
# she starts to pass by but is drawn back by something in salome s voice
# then she looks at her closely
# salome notices and grows quiet a bit apprehensive
# karla comes closer and closer to inspect salome
# karla is growing noticeably excited as salome grows fearful
# salome never looks into karla s eyes
# always she looks down or away
# p
# 4 karla step into the light
# salome beg yo pardon maam
# karla step into the light please
# salome yessum but ah ai nt done nothin maam
# no maam
# karla i just want to look at you for a moment
# you look like
#
#
# but this
#
#
# you have to be
#
#
# my god
# my god
# it s you
# salome oh no maam my
# i can see it

# %% [markdown]
# ### Extract sentences that contain the word "mouse."

# %%
wordsInCorpus = 0
mouseText = []
AllText = ""
for each in textList:
    words = each.split(" ")
    for word in words:
        wordsInCorpus += 1
        
    if " mouse " in each:
        mouseText.append(each)
        AllText = AllText + " " + each

AllText = AllText.strip()
print(wordsInCorpus)
print(len(AllWordsList))
# Out:
# 28132499
# 28132499

# %% [markdown]
# ### Check the concordance table for sentences containing "mouse."

# %%
from nltk import *
retokenize = RegexpTokenizer("[\w]+")
text = Text(retokenize.tokenize(AllText))
text.concordance("mouse")
# Out:
# Displaying 25 of 450 matches:
# t a creature was stirring not even a mouse the stockings were hung etc lights s
#  lights slip up on mature ernie dead mouse just like he s been for twenty years
# e s been for twenty years he s blind mouse like i said i sort of lost my head f
#  the string and beads go flying into mouse holes in the corners the finance dir
# orners the finance director used the mouse and expanded a window i want a drink
# ight of drew s nose twitching like a mouse s but douggie s as disdainful as a c
# ainful as a cat s ida there s been a mouse in the pantry she said shaking the c
# he handeye coordination of using the mouse and learning how to type p i crept l
# to type p i crept like a little damn mouse up the last steps and looked over th
#  the edge of the bed she can see the mouse rolling that pearl to its hole in th
# wn the aisle or the tiny feet of the mouse that might be chasing it p the mouse
# mouse that might be chasing it p the mouse in the darkened grand isle church ro
#  toward its hole or does not a field mouse maybe first on the scene of the orig
# im a grownup girl in boxfresh minnie mouse shoes if there had been a mouse in h
# nnie mouse shoes if there had been a mouse in hiding there he escaped her but t
# oy s foot did not she was quiet as a mouse most of the time and she was nt one
# s fly from her mouth they called the mouse algernon if the operashun works ill
# if the operashun works ill show that mouse i can be as smart as he is i must be
# ust be getting smart to beat a smart mouse like algernon burt said no algernon
#  said no algernon is a very specshul mouse with an operashun like mine and he w
# nd called algernon once but he was a mouse and we used to run races together no
# e used to run races together now the mouse can grab some of the headlines now g
# b some of the headlines now get this mouse out of your house now use them brush
# se now use them brushes and get that mouse out of your house aunt bianca well i
#  with everyone acting like the white mouse trapped within the tikumtokum of an

# %% [markdown]
# ### Perform morphological analysis: Extract content words.

# %%
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Noun or Predicate
def tokenizerPOScontent(doc):
    stop_words = set(stopwords.words('english'))
    tagged_list = pos_tag(word_tokenize(doc))
    contentWords_list = [t[0] for t in tagged_list if "N" in t[1]  or "V" in t[1]]
    filtered_contentWords = [w for w in contentWords_list if not w.lower() in stop_words]
    length_contentWords = [w for w in filtered_contentWords if len(w) > 2]
    return length_contentWords

mousePOSText = []
for each in mouseText:
    print(" ".join(tokenizerPOScontent(each)))
    mousePOSText.append(" ".join(tokenizerPOScontent(each.strip())))
# Out:
# offstage twas night christmas house creature stirring mouse stockings lights slip mature ernie
# mouse like years
# mouse like said sort lost head
# let get generations dagenhams spinning graves rip string beads flying mouse holes corners
# finance director used mouse expanded window
# want drink gem announced side wall interrupting reverie sight twitching like mouse cat
# ida mouse pantry said shaking cookie bag
# cohen hoped day know machine connect internet read logic machine language coordination using mouse learning type
# crept like damn mouse steps looked edge bed
# see mouse rolling pearl hole sacristy shelf father keeps hosts
# silence ship cuts water hear pop monstrance roll aisle feet mouse chasing
# mouse isle church rolls pearl toward hole
# field mouse
# scene killing discovered lines poem tattooed armpit victim send heart unarmed walk like girl prostitute rim grownup girl minnie mouse shoes
# mouse hiding escaped boy foot
# mouse time let things fly mouth
# called mouse algernon
# operashun works ill show mouse
# getting beat mouse like algernon
# burt said algernon mouse operashun like mine animals stay
# told friend called algernon mouse used run races
# mouse grab headlines
# get mouse house
# use brushes get mouse house
# aunt bianca thought disturbances everyone acting like mouse trapped within tikumtokum diophantine challenge box model came alabaster mother pearl
# brother watched sometimes catch lose mouse times remembered bite paws
# killed ate cat kittens mouthful fur halfdigested mouse seem worth effort avoided
# mailman stopped front house day mother cavelike darkness kitchen polishing breakfast pabst blue ribbons way ice cubes grandma paul grass ramada skirt mickey mouse sweatshirt grinding acorns managing perspire
# showed smiling girl standing mouse amidst crowd disneyland
# regan walked doctor lowered voice exercise since alvirah meehan hear mouse sneeze rooms
# time discovered become fire engine bird mouse bee things lisp
# creature say mouse sponge
# adventures world needed redeeming adventures randy mouse rocinante horse story
# done jeff comes bearing mouse lightweight habitat
# mouse litmus turn microorganisms
# beauty habitat litmus mouse
# time wait around mouse feast
# dropped serpent mice snake came began coil uncoil slithered around grabbed mouse hind leg
# looked around victorianstyle house occupants group gathered around video screen watching buster keaton film ones mouse guys riding across living room carts call skates dining room group ones sitting reggiesystem computer geography lesson tell geography hear repeating word togo unison comer sat wise buddhasaurs blowing plastic horns library see diogenes shelving books yes books saurs type styles colophons bassinetsized hospital bed rolled window
# went arcade find dancing chicken replaced rat snake ate mouse nothing
# found mouse turds paper bits wasp nests bunches leaves creature
# let pretending tickle ran fingernail skin kneecap grabbed hand like mouse spider brought mouth like going eat
# without clumsy crowd horsemen trailed stream lycanthrope track mouse moonless night
# took mouse gabriel hand
# take bow tie turn mouse turns bow tie mouse
# mickey mouse shit
# disney announced plans build world middle orange groves drew cartoon showing mickey mouse tourist getup asking impoverished workers way magic kingdom
# year half ago told academy joke mickey mouse graduated let know case happened see drive car freaked
# yes live regret hemlock bay chapter near plum river maryland day october wind whipped leaves trees sun shining bright dilapidated barn painted years streaks washedout red left paint job charm left fbi agent dillon savich eased around side barn sig sauer hand taken discipline practice learned move sneak mouse agents wife feet behind covering fan direction wearing vests dozen agents working way side barn orders wait signal sheriff dade stand trees feet behind deputies sharpshooter sights trained barn operation going savich supposed everyone although spoke hoped continue way planned chances things get screwed deal choice barn likedthere hayloft corners sort operation nooks crannies ambush plain places fire storm bullets place tommy tuttle dubbed warlocks media hole
# looked mickey mouse watch
# name boy mouse women age named michelle heather courtney
# carried wind dissolve rose stooping doorway tall whiskered come dressed flannel like mouse nutcracker taken ceremony dressup mother
# night door tower pawed mouse hair smiled nibbling claude scooted stairs serving girls
# mouse changed
# reason mouse turned moody
# let appearance seed dresser nobody wanted around man like mouse got company man
# mean wanted see mouse work changed apartments month step landlord used say
# mouse surprised tuesday night racket broke apartment door
# someone worked knew keep style
# use trying argue mouse preaching mood
# yeah mouse said staring jelly glass
# laughed said yeah watching mouse
# spent night though knew girl
# morning etta talk man mouse friend
# saw mouse put knife man gut
# mouse strolled
# junior waved piece furniture mouse put hand air
# git junior say mouse stiletto buried inch field hand gut
# see mouse smiling see face grow pale
# think beating listening mouse respect
# mouse word
# knew wanted trade forget etta drive pariah care woman thing got mad played money caught lie
# mouse
# lay dark thinking time mouse saved life
# thought mouse said tried thank
# bruno grave years mouse languished state prison chino manslaughter
# thinking mouse set teeth edge
# story told butterfly died field brazil fell ground made mouse move shoot grass bend everything thousands thousands miles
# books pulled bookcases chairs tipped computer keyboard mouse dangled edge table cords insult waited square middle carpet glistening pile dog poop animal stinking room
# mouse looked know pounce thing hairy hands groping heard door screaming woke
# cycles peak times night dreams going everybody head intermingling influencing mad logic friend village described baby turns cistern mouse hides breasts monster disappears dream dog since pig seen smelt particularity
# lock door saw cat gnawing mouse head exposing crimson essence
# mouse scurried rails
# expected electrocuted rail sparks shrill squeal dun mouse astonished suddenness end
# mouse twitched hand desperate giggled enjoying powerthere girls around toountil mouse somehow swung upwards bit palm needles piercing skin
# screamed let mouse scurried
# plastic stairs placed front desk behind frog sat clicker mouse slapped paw slapped video remote pad
# frog clicked mouse monitor went dark
# moment left eyeball tucked socket belonged moment migrated cheek like mouse peeking hole
# shabby mouse remembered robed gold velvet
# drugged mouse confined mesh bag escape got
# mouse disappeared
# mouse vanished
# year ago mouse come
# reached shoulder jabbed computer mouse searching messages others phartnyuedu
# joanna relinquished mouse amy clicked trash folder
# continues mouse
# daggett time saw mouse
# lay bed thinking opened eyes see mouse teeth eyes staring
# day opened store deliver something farm spring season horse tired walked came see thing alongside pups mouse lying half beside mother move panting broiling sun tongue hanging rotter deserve live dropped woods god knows night picked put pups wagon getting leave creature like farm stopped asked water cool girl came help murphy
# disinfectant mouse traps sound like
# spected like mouse stead man though
# story told butterfly died field brazil fell ground made mouse move shoot grass bend everything thousands thousands miles
# sat feeling mouse floating bottle beer
# woman meek mouse lives like
# mouse droppings said troy
# mouse crap
# mouse droppings said bug
# mouse fit places
# felt touch tongue throat nestling flesh like mouse seeking comfort
# know mouse puppet wanted sing
# knew mouse feel pulsing heart deep within fur
# mouse dived cover heading toward hole ground
# mouse landed dazed
# tossed mouse time
# mouse managed scramble paces caught
# rusty looked mouse pull claws
# time since moon dream time mouse escaped grasp
# told coraline training mouse circus
# day caroline everyone world see wonders mouse circus
# reason see mouse circus said man upstairs
# coraline think mouse circus
# headed deli snack allnight mouse hunt
# singing fish fish sings ring stomach carp caught court somewhereand cooked served table bite fish find ring ring lead man love mouse disguise man love
# bindy clicks mouse picture vanishes
# maggie clicks mouse button finds gazing face
# mind made clicks mouse send email button begins typing
# mickey mouse orlando
# speaking command cursor whatever person using mouse keyboard
# hope remember saucer milk dinah dear wish mice air afraid mouse know cats eat bats wonder
# kellen like mouse wandering machine run whether
# melody ejected supercapacity disk clicked mouse shut laptop banged lid closed
# mouse born parents litter born
# father mouse held mouse
# dieu mouse baby
# mouse arrived castle luggage visiting diplomat
# mouse mother held handkerchief nose waved front face
# name mouse despereaux sadness despairs place
# mouse mother name antoinette looked reflection gasped aloud
# antoinette touched eye makeup mouse father put bed made blanket scraps
# drops sweat peered like eyes field mouse mustache
# sober church mouse clearspoken valedictorian
# cleaning garage resting place sorts animals months uncovered mouse middle giving birth
# mouse eyes unlike ginger whiskers extended moving air trying size situation trying decide flight response though condition choice
# ginger stopped talking mouse ducked built birth placed garage closed door
# look sasha said pointed glove mickey mouse moving float
# corner mouse body trap desiccated fur mistaking
# uses polyethylene glove coated cocoa butter hand runs mouse left
# holds mouse tail waves front glass
# cat knows mouse knows control happens crane places cover aquarium turns valve canister connected cover
# crane drops mouse aquarium
# mouse runs corner cat drops prowls
# mouse turns squeals cat retracts fur spiked begins ramming glass side desperate escape
# crane takes syringe presses drop liquid onto mouse neck
# mouse pauses stands legs hisses charges cat throat
# minute squealing hissing mouse soaked cat
# alfred wont bruce cat mouse infect masses fear prick fearlessness fails mighty giant
# panics trying scrape gunk legs manages get hands stuck hardening mess process like mouse gluetrap
# watch hilights songs mouse moves device clicks
# patience touching cheek know know midnight thought mouse pillow
# owl swoops screech nailing mouse hear squeal
# cat mouse thing
# leaves mouse follows heroine tunnel
# video cgi engineer works mouse altering footage marco watches behind
# afraid said deer mouse friend
# husband rye mouse gone ereth log talk
# mouse caused fuss ragweed
# used chatty mouse said
# mouse change looks
# canals smell goat grass clippings steam sealouse soup smells sea caves babies smell mouse holes women smell desire
# edge pool standing within radiance moon mouse lifted head sniff air
# cast seed reached mouse squealed iron talons pierced flesh squeak fear surprise
# shrill echoes mouse cry lost wind remained life within went business without notice concern
# hunched like wounded mouse since workfolk brought
# roger nudged mouse fingers
# aimed camera past mickey mouse phone began taping
# basement afternoon screwdriver noticed mouse trap downstairs
# throw mouse patsy said obliging smile
# mouse pressed trap incisors showing sides mouth patsy said
# saul grunted loosened spring picked mouse tail felt like rubber
# feeling moment desolation nothing breeze feeling threw mouse toward field body arcing figure horizon radio transmitting pulsing light tip landscape excited
# guess news patsy said mice mouse
# throwing load mickey mouse stuff head icing
# mother hear field mouse lot fluffy neighbor cat stalking
# take promise church mouse interfere work
# father asked set soda mouse pad
# fairies failed see laugh faint shadow crossed mouse
# sounded mother father warning hammy mouse timmy goes
# continues chapter mouse years magazines claimed man hoofed moonenuk wolfglove day front house blowing snow twilight winter
# behind water barrel stood dirt damp mouse turds excited company
# let chips spin darkness table mix caribou hairs mouse turds carpeted hewn floorboards
# made mind face try make peace registered panicked mounted ridden ranch like mouse bolting hole wall
# magician melded mob pedestrians riker remembered exhale mallory stood keep track mouse crowd
# buy mickey mouse pixy stix dog picture nose dusted sugar powder chews gumdrops
# imagines walls hiding decay steel beams crumbling dust insulation chambered mouse nests wires wrapped fraying cloth
# office beyond nothing mouse chewedon newspapers
# grinned like cat mouse tail hanging jaws
# moth window screen skitter mouse box trying trying
# castellano hate mickey mouse bastard
# magnified shows mouse ear grown back
# guerillas anchor mouse looks like mouse ride flatbed cargo
# mouse hate going fuckin river
# mouse match soaked water dripping
# mouse anchor scar team leap flatbed
# mouse looking leave
# mouse nods running hide boat shed
# mouse
# grabs mouse gunhand
# mouse runs screaming door grabbed thing
# owl hoot mouse rustle broke silence pine tree stood undisturbed breeze
# mouse grave
# mice got guess mouse herdmans
# prize knew belinda loved bit mouse went sleep brighttime
# feeling body crunched like mouse corner light coming
# kathryn eyes hair color mouse pelt sister eyes hair
# mouse lying bellyup
# mouse looked like patch
# mouse stretched body breathforepaws straining hind ones tail dragged behind
# live ask mouse leave
# nathan half realize police looking mouse killers
# row row row boat around lake walk talk piece cake ride ride ride trolley stop visit dance dance choochoo visit zoo casino round round depressed tornado search search search find lose mind seek seek like mouse find fun house poetry
# expect mouse gnawing hole right gateway freedom
# pet mouse named ben
# years knowing game cat mouse
# make tale war pulp find hoon enemies released snake room mouse hole everyone thought bullet hole bite cops looked serpent remained coiled behind radiator
# email worded sent contained way answer email address prevent reveal name bit cat mouse focus interest without leading doorstep
# country mouse grown suburb city made forays mother friends shop see show visit museum
# mouse born parents litter born
# father mouse held mouse
# dieu mouse baby
# mouse arrived castle luggage visiting diplomat
# mouse mother held handkerchief nose waved front face
# name mouse despereaux sadness despairs place
# mouse mother name antoinette looked reflection gasped aloud
# antoinette touched eye makeup mouse father put bed made blanket scraps
# nebraska get around cows fredreeq joey city mouse country although joey country exmodelactress lived
# behind pillar center room came scuffling like mouse flinching bed straw
# let mouse reach wipe hand arm
# night clicked mouse looked screen silvery mac powerbook laptop dresserdesk room commanderthere connection reliableand got blog
# baby breathes eyes face husband hovering earnest needy man known since college man share bathroom man cried women thinks know plucks hairs afraid raisins remind mouse droppings
# mouse pads desk drawers
# swooped pouncing burst feathers fur field mouse working way homewill wiped palms leather eyes set squint studied world thought spoke actedhis years seemed feet pounds face scarred fights hands scarred fishhooks shoulders callused harness wore plowed father fieldsnorth hadmarched washington army
# finger mouse centered dash
# grace pulled hank called hair shoulder waved sister
# mouse bookworm
# time since member mickey mouse clubhouse
# like officers dan patience comes training novices city mouse emerge day woods tutelage understanding wildlife firearms
# something nibbled rearward memory like mouse corner meal bin
# anything sit trembling like mouse afraid step
# like mouse crept mountain using trees bushes cover clinging bare rock
# state squealed like mouse hamburger press slammed door cause blizzard plaster flakes
# quit squeaking like trapped mouse leaving
# look like mouse gon
# corner chamber mouse scampered
# collecting pellets made mouse skeletons year science project
# forget universe said turned face front mouse deer enclosure
# worked way college playing mouse park california
# think mastered art teleportation dear said time tried attempting call client air ended quaint soda fountain disneyland sweaty lad mickey mouse suit giving welcoming hug
# bitterman roared sophie feeling like mouse navigating maze zigzagged way around cubicles reach office end room
# click click click clicked mouse fingers tingled hand ached determined make perfect
# makes swimmyheaded hold squirming mouse snake mouth refer jobs sitters
# bibby turned computer click mouse rotated hayley see
# amber came flying downstairs wearing blouse tweed skirt leather minnie mouse pumps put trying look
# tom succeeded job though mouse wife disappointment
# norman wife sons marquess told continues glanced mickey mouse clock gretchen desk
# mouse melvin lights throat toddy bottle faint sizzle whitepink bullet shoots trees spirals branches
# mouse gazed kind prophet saying time make pay hell inflicted people
# blond man beside accent
# time measuring penises mouse said voice rippling emotion
# time talk strangers heart pounded hear mouse voice tried squeak something clever
# kids game cat mouse players
# like mouse felt terrified prospect lay meeting liege lord
# clicked mouse close window
# draft jessup estate accounting tucked pink alligator leather tote bought consolation gift confrontation patrick scooted chair clicking button wireless mouse hibernate computer made exit
# grimaced said think mouse trying thump way
# named swore mischief mischief boy avatar god lynx goes accompanied scurry mice
# leaned whispered mouse
# years cat mouse jet done playing
# saw crabbe manchu jersey emblazoned melody hand martini waiting crouched like thickset housecat watching mouse hole
# mouse sat chair beside bed without moving
# standing griping though people need get finding cheese like mouse characters book sniff scurry
# miles tied flags bow played cat mouse coast guard ships patrolling channel rosas saw vieques fishing boats slicing water join
# magic forcefeedback technology ifeel creates illusion touching icons links menu items bumping vibrating move mouse drag cursor screen
# mouse user interface like windows born hothouse silicon valley ended making lot money apple microsoft
# lead associate case tony knight deluged van horn carton mouse rat electrocardiograms
# cat mouse sonarman board destroyer waller homeported norfolk virginia
# playing cat mouse submarine night see couple yards
# systems peripherals keyboard mouse connected computer via
# daddy roth fink glared convention mickey mouse heart attack manti utah
# president bush decision fund work existing colonies stem cells colonies hit snag week revelation stem cells cultivated using mouse tissue
# mouse cells provide ones nutrients growth factors crucial survival proliferation
# day july someone america walked storefront clicked mouse dialed number signed cellphone service
# example restrict food mouse rat pups born pups begin develop diabetes percentage
# example mouse rat models get diabetes without difference body weight
# mouse sit desktop reach maneuver position concern
# gambles proved spawning internet computer mouse stealth aircraft chip makes cell phone work advances meant research outofthebox time sensors seem today
# signed schwab logged aol keyboard mouse made bets intel aftermarket fund
# using wireless keyboard mouse evensky leads clients dozens scenarios illustrated charts
# front computers hands keyboards mouse pads people attached ideas plans flicker screen
# room shook money mickey mouse bank
# stuff roach mouse repelling steel wool cavities caulk tack pieces aluminum flashing plywood holes caulk around
# photograph designed money get feeling step creditcard transaction mouse click
# pocket concert use controls clever rotateclick wheel found mouse allows select tunes make feature adjustments
# mouse clicks create radio station tune membet stations
# cameron photograph pick multimedia library everyone got hobby mine making digital images spin mouse magnify view details
# addition powerdesk offers zip tools program extends compression features tricks like zipping files attaching email zipping files windows explorer mouse click backing documents
# weed cousin mustard plant arabidopsiswhich plant scientists lab mouse researchersis leading hasegawa scientists around world understanding plants withstand stresses
# wwwspolegov mouse click
# pong video game went dream reality inkjet printer video recorder mouse computer else take granted information age
# home franchises bob builder barney hit added creature menagerie animated mouse called ballerina
# study university minnesota researchers isolated cells adult mice grew dishes injected mouse embryos developed nerve liver types cells
# study scientists institutes health work cells mouse embryos developed brain cells produce dopamine used treat disease
# piece spyware watch shoulder browse web record mouse clicks broadcast information computer marketing purposes
# facing cutrate prices chains expected get gobbled mouse snake pit
# photograph cotton mouse danger extinction cat predation
# seem like deal lose florida ponce beach mouse vanished estate development predation cats iucn list put
# danger pondering questions coming solutions opt play game cat mouse beattheheat guide looking head toe photograph face weather changes routine sunblock day
# goal engineer mouse immune system used generate antibodies
# biologists known decades immunize mouse cancer cell protein cell mouse respond generating antibodies fight foreigner effect anticancer antibody
# inject cancer cell mouse generate antibodies specialized target cancer cells put
# arrived guise antibodies mouse origin function
# antibodies came constructed joining gene generates region antibody base genes generate regions mouse antibodies outer arms resulting chimera mouse twothirds
# whereas chimerics mouse humanized antibodies tenth
# mouse came tips arms antibody part region binds target
# problem tips mouse antibody grafted onto framework antibody grip target
# cary queen biologist working institutes health created algorithm analyze fit mouse tips framework figure molecules framework adjusted leave mouse region sitting atop arms binding target
# method number mouse immune systemlonberg dream medarex pursued competitor abgenix
# put target molecule mouse get antibody antimouse antibody response worry
# make mice researchers cloned gene segments generating mouse stem cells grew mice maturity
# inactivate genes produced mouse antibodies set mice bred lines
# photo color mouse medarex nils lonberg helped develop mice produce antibodies injected molecules
# photo color lab market geoff davis led team engineered version mouse produces antibodies
# disparities curiosity intelligence seem arise mouse moms bestowed care grooming pups brief disappearance
# thymus mouse cells day apoptosis scientists estimate
# nature shigekazu nagata osaka university school japan colleagues reported mouse macrophages secrete protein called milk fat globuleegffactor mfge8 binds cells killing
# system programs run server desktop computer sends keystrokes mouse movements server server work sent displayed desktop screen
# michael lemonick fall walt disney claim assets cartoon character called mickey mouse films featuring rodent idea imagined adding sound tracks films
# give movie run told disney give make mouse
# management written dorfman directed peter segal dave buznik sandler mouse afraid roar
# studios split profits movies since pixar cgi movies grossing mouse house films take jobs wants portion money
# moreover cultured using mouse cells growth medium raising fear carry mouse dna mouse viruses
# quimby mouse fantagraphics pages collects series comics style themes formed
# unlike cell phones switch wifi antenna shortrange radio found cordless computer mouse keyboard sending bits data
# run box launch desktop icon mouse button launching apps make javascript file open run box
# extension file desktop launch toolbar use right mouse button drag file locations choose create shortcuts
# rightclick drag windows folders release mouse button choose create shortcuts
# copy adds commands copy move menu see drag drop files right mouse button
# thought tom jerry mickey mouse burns line laid schemes mice men
# look inside circle folder rest mouse moment
# mouse computer acts point click folders files connectivity things jobs get mass market
# rightclick mouse see deliver car buddy
# disney dream desk kids blue accents speakers mouse ears perched atop monitor
# throw bluetooth wireless keyboard mouse thing needs cable power cord
# spears told people said detail lawyers advised couple opted prenup agreement signed marriage license wait grace period inking prenup filed signed license federline told people week spears time intervention people movies seen actors beings playing ones perform set constructed artisans lights operated fellows quaint guild titles like gaffer boy maybe time mean thing holds century art form people let pixels behaved simulate sea creatures shark recreate manhattan shangrila sky captain world tomorrow visualize future dystopia ghost shell innocence wave wand click mouse moviemaking toy revolution machine start remained century generation got schooling front teeming screens make movies seem like life cooler telegram age generation directors moving analog digital want make films hit button reality films aspiration cartoons uncle walt cartoons kind drawings singing dwarfs teapots looking trio tale people shrek megahits mode dreamworks cartoon resembles work competitor pixar antz match bug life shrek counter monsters inc goes pixar finding nemo tilt craft heart oscar fish voiced smith dude mouth becomes hero pretenses saying slew shark lino robert sea feared propel plot lino son jack befriends oscar adoring friend angie rene zellweger jauntiest shows oscar work car wash shark tale jaws refreshes piles gags film sitcom air fullofhimself hero grate ingratiate sky captain bit film tale kerry conran script plot lifted sifted lots films wizard lost horizon dozen newspaper comedies technique star conran devising decomeetsdelirium universe projected onto screen front game clueless stars law flyboy gwyneth paltrow news gal moms get house home order fall beach towels flipflops book bags blankets housekeeping sweat janet nelson though mother works relations manager maid services company maid service franchise nation maid husband bob janet telecommuting days week home iowa traveling omaha days bob stays home care kids cleaning years scrubbed floors done laundry cooked dinner
# shareholder revolt headnote pressure mouse house board pick eisner successor defend chairman
# disney directors want entrust mickey mouse duck executive gave pets
# built culture ground ebay management style welcomed inside mouse house
# get paper change gene effect cancer mouse paper gets published science nature journals
# fact want understand war cancer gone mouse place start
# poster lessons feel biblicalit shows example zebrafish chicken hedgehog shrew kissing cousins look like macaque platypus mouse leap
# mouse gene gene rest mouse
# find compound cures hypertension mouse know work says chabner years ran cancertreatment division nci
# researchers try approach cancer knocking neutralizing gene knocking mouse causing tumor appear
# homer pearce ran cancer research investigation research fellow drug company agrees mouse models determining whether drug work humans
# mouse model used
# promising drugs clobbered mouse cancers failed man hundreds thousands compounds discarded years agents
# exciting see tumor shrink mouse man know drug
# read word response newspaper story cancer drug like mouse tumor regression predictor progression disease
# undo culture created rois grants launched metoo mouse experiments shifting picture
# kolcuns became family block computer design pointandclick mouse remember thinking friend george cooler rest
# holding keys mouse buttons sidestep security models
# instance secure touch mouse list wwwfellowescom combines fingerprint scanner omnipass password management encryption software softex
# coauthor senator conrad burns rmontana said canspam controlling assault pornography marketing bill name supposed put end email people see day inboxes imposing penalties kingpin spammers allowing people opt marketing mailing lists mouse click
# transforms mouse stem cells beating heartmuscle cells scripps researchers report gone modifying mice breed rodents scientists report overexpression k14noggin gene led deformities claws hairs eyes feet
# author argues caught game cat mouse bacteria unleashed bedlam
# parkinson spinning rod cast mouse lure front fish
# gave version mouse lure wet weighed ounces
# nothing like mouse jockey picturing
# cats mouse deterrent die catching pests
# kids adults adore tale mouse adventures family
# animation action blend tale family member mouse named stuart voiced michael fox
# imagine adoration wonder engendered boysages hoisting onto seat watch mighty mouse float
# work karel svoboda spring harbor laboratory york reveals percent synapses mouse brain change course weeks
# mouse retains memories scientists know
# technique manipulate mouse genes brain cells produce fluorescent protein
# pinon mouse resident
# mouse mammals region moved homes
# thanks computer scientist oren answer mouse clicks
# comes dna chimp mouse rat
# darlene liked decker mouse sander used take finish notch
# leave show shadows mouse pointer checked make pointer find screen drag keep box checked
# reduce delay submenu appears hover mouse pane click hover change time milliseconds like computer appear icon screen clean desktop doubleclick desktop choose icon click computer
# power moves morgan became elected georgia mouse representatives county
# mccarthy isaacson chat sip tea baker uses computer mouse adjust telescope
# years tinkering coaxing resulted generation islet cells stemcell researcher institutes health rashly said years ago stem cells made jump hoops claim generated insulinproducing cells mouse cells
# stadium owners welcome technology help get use field mouse clicks takes change field gridiron soccer pitch
# years darpa wants mouse finger
# lab mouse discovered heberkatz wistar institute fall amphibians mammals
# term life author say time mickey mouse fall domain mouse term extended
# logitech mouse packaging perforated corner bend splitting seam
# microbes permitted mice metabolize nutrients lost appeared manipulate mouse genes way increased animals capacity store team reported
# harrison recommend cheese food mouse bait preferring cotton ball bit water
# want impress girlfriend mouse trap cotton ball seconds mouse trying get
# mice rna transcripts produced genome nonproteincoding outnumbering transcripts code proteins according study group scientists called annotation mouse consortium
# jonas brothers lines vines trying times stars poprock jonas brothers disney boys series mickey mouse channel going take taylor swift dis lying
# allwine voice mickey mouse years starting died diabetes complications
# place hand mouse click
# strategy find characters lived inside people came walt disney everyone talked president herb scannell said july issue guide
# mouse feeling squeeze
# sometimes mouse friend business making tracking reservations gone hightech
# remember bobs fireball shoot chutes pairochute ride mouse said stepson rollercoasters bobs fireball
# wireless keyboard mouse fmc capable working word processing surfing internet
# means according seers wireless mouse remote control need give way sort voicerecognition system
# coming afternoon showing jane spigel declares vote mickey mouse bush election
# manson depicted antimickey mouse helnwein works painter credits helnwein gottfried support encouragement show
# beneath placid surface land mickey mouse pals discontent deceit war
# sales soared today company boasts characters including mickey mouse simpsons spongebob snoopy
# using mouse navigate give sense scale monumentality snyder says
# advocates legislation argue number stem cell lines needed material become contaminated time mouse skin cells placed bottom culture dishes used research
# kitten met mouse scared claws story mirrored boy frustration finished resolution
# addition printing embroidering apparel colorworks supplies businesses mugs mouse pads marketing items warehouses fills orders online retailers
# say drop mouse poem watch probe way walk inside poem
# rougher englishspeaking citizens york coined word sooterkin describe animal size mouse women use stoves breed skirts
# school web site parents access mouse click
# sound used train surgeons rehabilitate patients haptics enhancement reality technology gives users touch feel objects interact device like mouse glove
# immersion vice president sales marketing joseph dinucci said device thought mouse navigates systems car
# playing cat mouse porter men terrorized enemy whaling fleet
# journey robert lawson published amusing tale mouse lived ben franklin philadelphia row house accompanied founding father wherever went perched cap altered purpose
# lawson titled book ben purported version manuscript mouse handwriting found years workmen remodeling house
# rainforest mouse deer hoofed creatures
# significance mouse owl ant realize everyone reading book place journey toward saving money
# chapter present levels steps taken timid mouse wise owl ant
# timid mouse mice creatures
# authors took mouse school though considering happened sat recommended
# one victimized mouse victims called oppressors
# cat stalks mouse part seeking christmas emotion

# %% [markdown]
# ## Step 2: Extract Context Words
# **Objective**: Use a window collocations to identify collocations of "mouse" in the corpora.

# %% [markdown]
# ### Apply window collocations to calculate co-occurrence frequencies and individual word frequencies.

# %%
wordType = set()
for each in mousePOSText:
    eachSplit = each.split(" ")
    for word in eachSplit:
        if word != "mouse":
            wordType.add(word)

wordList = list(wordType)

print(wordList[0:10])
print(len(wordType))
# Out:
# ['works', 'analyze', 'disk', 'generate', 'desperate', 'vice', 'mischief', 'needed', 'read', 'hell']
# 2550

# %% [markdown]
# ### Calculate co-occurrence frequencies and filter words with a minimum frequency of 5.

# %%
wordFreqDict = {}
for each in wordList:
    wordFreqDict[each] = 0
    
for each in mousePOSText:
    eachSplit = each.split(" ")
    for word in eachSplit:
        if word != "mouse":
            wordFreqDict[word] = wordFreqDict.get(word) + 1
        
wordFreqDicSorted = dict(sorted(wordFreqDict.items(), key=lambda x: x[1], reverse=True))

CoOccurringWords = []
collocations = []
for key, value in wordFreqDicSorted.items():
    if value > 5:
        CoOccurringWords.append(key)
        collocations.append(value)
print(len(CoOccurringWords))
print(CoOccurringWords[0:10])
print(collocations[0:10])
# Out:
# 85
# ['like', 'said', 'mickey', 'cat', 'cells', 'time', 'see', 'computer', 'get', 'years']
# [51, 25, 25, 24, 20, 19, 18, 17, 16, 15]

# %% [markdown]
# ### Calculate individual frequencies of co-occurring words.

# %%
CoOccurringWordsFreqDict = {}
for each in CoOccurringWords:
    CoOccurringWordsFreqDict[each] = AllWordsList.count(each)
    print(each, AllWordsList.count(each))
# Out:
# like 66617
# said 82556
# mickey 282
# cat 1876
# cells 1488
# time 46556
# see 30031
# computer 3001
# get 35091
# years 30281
# man 27737
# mice 317
# click 564
# house 17781
# mother 17251
# way 30753
# around 24755
# made 23898
# people 33115
# work 19069
# make 24359
# day 23424
# know 34855
# front 9820
# hand 15580
# looked 16567
# used 11202
# field 4619
# trying 8273
# hole 1890
# antibodies 114
# put 13807
# face 16348
# father 15703
# came 15589
# screen 2415
# told 15159
# let 14909
# night 15382
# eyes 19315
# called 12430
# cancer 2405
# clicks 165
# behind 12137
# keyboard 241
# button 928
# room 16219
# find 12461
# clicked 301
# using 4775
# bed 6595
# everyone 6349
# scientists 1746
# got 22345
# tale 907
# friend 5939
# though 14908
# desktop 219
# door 13992
# name 10515
# gene 604
# place 14773
# feeling 4252
# antibody 46
# disney 414
# thought 18131
# thing 13074
# since 14693
# air 8791
# went 13643
# hear 7049
# stem 562
# cell 2354
# born 3275
# use 11048
# world 19641
# run 7434
# head 18096
# game 6869
# take 20000
# films 944
# water 12512
# move 6034
# money 9402
# corner 3379

# %%
freqCoWord = []
freqTargetWord = []
targetword = []
wordsInCorpusList = []
targetwordCount = AllWordsList.count("mouse")

for key, value in CoOccurringWordsFreqDict.items():
    freqCoWord.append(value)
    freqTargetWord.append(targetwordCount)
    targetword.append("mouse")
    wordsInCorpusList.append(wordsInCorpus)
    
print(freqCoWord[0:10])
# Out:
# [66617, 82556, 282, 1876, 1488, 46556, 30031, 3001, 35091, 30281]

# %% [markdown]
# ### Generate the final dataset.

# %%
import pandas as pd
collocationTable = pd.DataFrame({'Co-occurring words':CoOccurringWords,'Target word':targetword,'Collocations':collocations,'Freq co-occurring word':freqCoWord,'Freq target word':freqTargetWord,'Words in corpus':wordsInCorpusList})
print(collocationTable)
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 0                like       mouse            51                   66617
# 1                said       mouse            25                   82556
# 2              mickey       mouse            25                     282
# 3                 cat       mouse            24                    1876
# 4               cells       mouse            20                    1488
# ..                ...         ...           ...                     ...
# 80              films       mouse             6                     944
# 81              water       mouse             6                   12512
# 82               move       mouse             6                    6034
# 83              money       mouse             6                    9402
# 84             corner       mouse             6                    3379
#
#     Freq target word  Words in corpus
# 0                564         28132499
# 1                564         28132499
# 2                564         28132499
# 3                564         28132499
# 4                564         28132499
# ..               ...              ...
# 80               564         28132499
# 81               564         28132499
# 82               564         28132499
# 83               564         28132499
# 84               564         28132499
#
# [85 rows x 6 columns]

# %%
collocationTable[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 0                like       mouse            51                   66617
# 1                said       mouse            25                   82556
# 2              mickey       mouse            25                     282
# 3                 cat       mouse            24                    1876
# 4               cells       mouse            20                    1488
# 5                time       mouse            19                   46556
# 6                 see       mouse            18                   30031
# 7            computer       mouse            17                    3001
# 8                 get       mouse            16                   35091
# 9               years       mouse            15                   30281
# 10                man       mouse            15                   27737
# 11               mice       mouse            15                     317
# 12              click       mouse            14                     564
# 13              house       mouse            13                   17781
# 14             mother       mouse            12                   17251
# 15                way       mouse            12                   30753
# 16             around       mouse            12                   24755
# 17               made       mouse            11                   23898
# 18             people       mouse            11                   33115
# 19               work       mouse            11                   19069
# 20               make       mouse            11                   24359
# 21                day       mouse            11                   23424
# 22               know       mouse            11                   34855
# 23              front       mouse            11                    9820
# 24               hand       mouse            11                   15580
# 25             looked       mouse            10                   16567
# 26               used       mouse            10                   11202
# 27              field       mouse            10                    4619
# 28             trying       mouse            10                    8273
# 29               hole       mouse            10                    1890
#
#     Freq target word  Words in corpus
# 0                564         28132499
# 1                564         28132499
# 2                564         28132499
# 3                564         28132499
# 4                564         28132499
# 5                564         28132499
# 6                564         28132499
# 7                564         28132499
# 8                564         28132499
# 9                564         28132499
# 10               564         28132499
# 11               564         28132499
# 12               564         28132499
# 13               564         28132499
# 14               564         28132499
# 15               564         28132499
# 16               564         28132499
# 17               564         28132499
# 18               564         28132499
# 19               564         28132499
# 20               564         28132499
# 21               564         28132499
# 22               564         28132499
# 23               564         28132499
# 24               564         28132499
# 25               564         28132499
# 26               564         28132499
# 27               564         28132499
# 28               564         28132499
# 29               564         28132499

# %% [markdown]
# ## Step 3: Collocation measures
# **Objective**: Apply the learned collocation measures to the dataset.

# %% [markdown]
# ### Expected Frequency
# The formula for Expected Frequency is:
#
# $$E = \frac{f(w_1) \cdot f(w_2)}{N}$$
#
# Where:
# - $f(w_1)$: Frequency of the target word.
# - $f(w_2)$: Frequency of the co-occurring word.
# - $N$: Total number of tokens in the corpus.

# %%
collocationTable['ExpectedFreq'] = (collocationTable['Freq co-occurring word']*collocationTable['Freq target word'])/collocationTable['Words in corpus']

# %%
collocationTable[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 0                like       mouse            51                   66617
# 1                said       mouse            25                   82556
# 2              mickey       mouse            25                     282
# 3                 cat       mouse            24                    1876
# 4               cells       mouse            20                    1488
# 5                time       mouse            19                   46556
# 6                 see       mouse            18                   30031
# 7            computer       mouse            17                    3001
# 8                 get       mouse            16                   35091
# 9               years       mouse            15                   30281
# 10                man       mouse            15                   27737
# 11               mice       mouse            15                     317
# 12              click       mouse            14                     564
# 13              house       mouse            13                   17781
# 14             mother       mouse            12                   17251
# 15                way       mouse            12                   30753
# 16             around       mouse            12                   24755
# 17               made       mouse            11                   23898
# 18             people       mouse            11                   33115
# 19               work       mouse            11                   19069
# 20               make       mouse            11                   24359
# 21                day       mouse            11                   23424
# 22               know       mouse            11                   34855
# 23              front       mouse            11                    9820
# 24               hand       mouse            11                   15580
# 25             looked       mouse            10                   16567
# 26               used       mouse            10                   11202
# 27              field       mouse            10                    4619
# 28             trying       mouse            10                    8273
# 29               hole       mouse            10                    1890
#
#     Freq target word  Words in corpus  ExpectedFreq
# 0                564         28132499      1.335537
# 1                564         28132499      1.655082
# 2                564         28132499      0.005654
# 3                564         28132499      0.037610
# 4                564         28132499      0.029831
# 5                564         28132499      0.933354
# 6                564         28132499      0.602061
# 7                564         28132499      0.060164
# 8                564         28132499      0.703504
# 9                564         28132499      0.607073
# 10               564         28132499      0.556071
# 11               564         28132499      0.006355
# 12               564         28132499      0.011307
# 13               564         28132499      0.356473
# 14               564         28132499      0.345848
# 15               564         28132499      0.616536
# 16               564         28132499      0.496288
# 17               564         28132499      0.479107
# 18               564         28132499      0.663889
# 19               564         28132499      0.382295
# 20               564         28132499      0.488349
# 21               564         28132499      0.469604
# 22               564         28132499      0.698773
# 23               564         28132499      0.196871
# 24               564         28132499      0.312348
# 25               564         28132499      0.332135
# 26               564         28132499      0.224578
# 27               564         28132499      0.092602
# 28               564         28132499      0.165857
# 29               564         28132499      0.037891

# %%
collocationTable.sort_values(by='ExpectedFreq', ascending=False)[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 1                said       mouse            25                   82556
# 0                like       mouse            51                   66617
# 5                time       mouse            19                   46556
# 8                 get       mouse            16                   35091
# 22               know       mouse            11                   34855
# 18             people       mouse            11                   33115
# 15                way       mouse            12                   30753
# 9               years       mouse            15                   30281
# 6                 see       mouse            18                   30031
# 10                man       mouse            15                   27737
# 16             around       mouse            12                   24755
# 20               make       mouse            11                   24359
# 17               made       mouse            11                   23898
# 21                day       mouse            11                   23424
# 53                got       mouse             7                   22345
# 79               take       mouse             6                   20000
# 75              world       mouse             6                   19641
# 39               eyes       mouse             9                   19315
# 19               work       mouse            11                   19069
# 65            thought       mouse             7                   18131
# 77               head       mouse             6                   18096
# 13              house       mouse            13                   17781
# 14             mother       mouse            12                   17251
# 25             looked       mouse            10                   16567
# 32               face       mouse             9                   16348
# 46               room       mouse             8                   16219
# 33             father       mouse             9                   15703
# 34               came       mouse             9                   15589
# 24               hand       mouse            11                   15580
# 38              night       mouse             9                   15382
#
#     Freq target word  Words in corpus  ExpectedFreq
# 1                564         28132499      1.655082
# 0                564         28132499      1.335537
# 5                564         28132499      0.933354
# 8                564         28132499      0.703504
# 22               564         28132499      0.698773
# 18               564         28132499      0.663889
# 15               564         28132499      0.616536
# 9                564         28132499      0.607073
# 6                564         28132499      0.602061
# 10               564         28132499      0.556071
# 16               564         28132499      0.496288
# 20               564         28132499      0.488349
# 17               564         28132499      0.479107
# 21               564         28132499      0.469604
# 53               564         28132499      0.447972
# 79               564         28132499      0.400960
# 75               564         28132499      0.393763
# 39               564         28132499      0.387227
# 19               564         28132499      0.382295
# 65               564         28132499      0.363490
# 77               564         28132499      0.362788
# 13               564         28132499      0.356473
# 14               564         28132499      0.345848
# 25               564         28132499      0.332135
# 32               564         28132499      0.327745
# 46               564         28132499      0.325158
# 33               564         28132499      0.314814
# 34               564         28132499      0.312528
# 24               564         28132499      0.312348
# 38               564         28132499      0.308378

# %% [markdown]
# ### Z-Score
# The formula for Z-Score is:
#
# $$Z = \frac{f(w_1, w_2) - E}{\sqrt{E}}$$
#
# Where:
# - $f(w_1, w_2)$: Observed frequency of the collocation.
# - $E$: Expected frequency.

# %%
import numpy as np
collocationTable['Z-score'] = (collocationTable['Collocations'] - collocationTable['ExpectedFreq'])/np.sqrt(collocationTable['ExpectedFreq'])

# %%
collocationTable[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 0                like       mouse            51                   66617
# 1                said       mouse            25                   82556
# 2              mickey       mouse            25                     282
# 3                 cat       mouse            24                    1876
# 4               cells       mouse            20                    1488
# 5                time       mouse            19                   46556
# 6                 see       mouse            18                   30031
# 7            computer       mouse            17                    3001
# 8                 get       mouse            16                   35091
# 9               years       mouse            15                   30281
# 10                man       mouse            15                   27737
# 11               mice       mouse            15                     317
# 12              click       mouse            14                     564
# 13              house       mouse            13                   17781
# 14             mother       mouse            12                   17251
# 15                way       mouse            12                   30753
# 16             around       mouse            12                   24755
# 17               made       mouse            11                   23898
# 18             people       mouse            11                   33115
# 19               work       mouse            11                   19069
# 20               make       mouse            11                   24359
# 21                day       mouse            11                   23424
# 22               know       mouse            11                   34855
# 23              front       mouse            11                    9820
# 24               hand       mouse            11                   15580
# 25             looked       mouse            10                   16567
# 26               used       mouse            10                   11202
# 27              field       mouse            10                    4619
# 28             trying       mouse            10                    8273
# 29               hole       mouse            10                    1890
#
#     Freq target word  Words in corpus  ExpectedFreq     Z-score
# 0                564         28132499      1.335537   42.975191
# 1                564         28132499      1.655082   18.146072
# 2                564         28132499      0.005654  332.415936
# 3                564         28132499      0.037610  123.560119
# 4                564         28132499      0.029831  115.623169
# 5                564         28132499      0.933354   18.700547
# 6                564         28132499      0.602061   22.422163
# 7                564         28132499      0.060164   69.062263
# 8                564         28132499      0.703504   18.237222
# 9                564         28132499      0.607073   18.472625
# 10               564         28132499      0.556071   19.369580
# 11               564         28132499      0.006355  188.079816
# 12               564         28132499      0.011307  131.553434
# 13               564         28132499      0.356473   21.176527
# 14               564         28132499      0.345848   19.817011
# 15               564         28132499      0.616536   14.497573
# 16               564         28132499      0.496288   16.329434
# 17               564         28132499      0.479107   15.199750
# 18               564         28132499      0.663889   12.685552
# 19               564         28132499      0.382295   17.172412
# 20               564         28132499      0.488349   15.042008
# 21               564         28132499      0.469604   15.366635
# 22               564         28132499      0.698773   12.323130
# 23               564         28132499      0.196871   24.347726
# 24               564         28132499      0.312348   19.123316
# 25               564         28132499      0.332135   16.775414
# 26               564         28132499      0.224578   20.627774
# 27               564         28132499      0.092602   32.557440
# 28               564         28132499      0.165857   24.147357
# 29               564         28132499      0.037891   51.178200

# %%
collocationTable.sort_values(by='Z-score', ascending=False)[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 2              mickey       mouse            25                     282
# 63           antibody       mouse             7                      46
# 30         antibodies       mouse            10                     114
# 11               mice       mouse            15                     317
# 42             clicks       mouse             8                     165
# 12              click       mouse            14                     564
# 3                 cat       mouse            24                    1876
# 4               cells       mouse            20                    1488
# 44           keyboard       mouse             8                     241
# 57            desktop       mouse             7                     219
# 48            clicked       mouse             7                     301
# 64             disney       mouse             7                     414
# 7            computer       mouse            17                    3001
# 60               gene       mouse             7                     604
# 45             button       mouse             8                     928
# 71               stem       mouse             6                     562
# 54               tale       mouse             7                     907
# 29               hole       mouse            10                    1890
# 80              films       mouse             6                     944
# 0                like       mouse            51                   66617
# 35             screen       mouse             9                    2415
# 52         scientists       mouse             7                    1746
# 41             cancer       mouse             8                    2405
# 27              field       mouse            10                    4619
# 72               cell       mouse             6                    2354
# 23              front       mouse            11                    9820
# 28             trying       mouse            10                    8273
# 62            feeling       mouse             7                    4252
# 73               born       mouse             6                    3275
# 84             corner       mouse             6                    3379
#
#     Freq target word  Words in corpus  ExpectedFreq     Z-score
# 2                564         28132499      0.005654  332.415936
# 63               564         28132499      0.000922  230.476425
# 30               564         28132499      0.002285  209.128350
# 11               564         28132499      0.006355  188.079816
# 42               564         28132499      0.003308  139.037838
# 12               564         28132499      0.011307  131.553434
# 3                564         28132499      0.037610  123.560119
# 4                564         28132499      0.029831  115.623169
# 44               564         28132499      0.004832  115.022738
# 57               564         28132499      0.004391  105.576705
# 48               564         28132499      0.006034   90.033648
# 64               564         28132499      0.008300   76.744494
# 7                564         28132499      0.060164   69.062263
# 60               564         28132499      0.012109   63.502710
# 45               564         28132499      0.018605   58.515301
# 71               564         28132499      0.011267   56.419781
# 54               564         28132499      0.018184   51.776107
# 29               564         28132499      0.037891   51.178200
# 80               564         28132499      0.018925   43.476826
# 0                564         28132499      1.335537   42.975191
# 35               564         28132499      0.048416   40.682341
# 52               564         28132499      0.035004   37.227457
# 41               564         28132499      0.048215   36.213598
# 27               564         28132499      0.092602   32.557440
# 72               564         28132499      0.047193   27.402058
# 23               564         28132499      0.196871   24.347726
# 28               564         28132499      0.165857   24.147357
# 62               564         28132499      0.085244   23.683443
# 73               564         28132499      0.065657   23.159628
# 84               564         28132499      0.067742   22.792425

# %% [markdown]
# ## Step 4: Demonstrating Semantic Change
# **Objective**: Create tables showing the shift in collocates between the 1850s and 2000s.

# %% [markdown]
# ### In the 1850s, "mouse" is associated with collocates like "rat," "house," and "animals"!

# %%
collocationTable.sort_values(by='Z-score', ascending=False)[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 0                 rat       mouse            12                      80
# 1                 cat       mouse            11                     335
# 18               lion       mouse             6                     400
# 16               deer       mouse             6                     503
# 17            species       mouse             6                    1607
# 9                door       mouse             7                    5044
# 12               room       mouse             7                    5374
# 6             nothing       mouse             8                    9325
# 8               house       mouse             7                    9067
# 11               eyes       mouse             7                    9764
# 3                made       mouse             9                   17960
# 10            without       mouse             7                   14053
# 14              found       mouse             6                   10439
# 15            thought       mouse             6                   10782
# 4                like       mouse             8                   19180
# 5                time       mouse             8                   22423
# 2                said       mouse            10                   41908
# 7                upon       mouse             8                   33929
# 13                man       mouse             6                   24071
#
#     Freq target word  Words in corpus  ExpectedFreq     Z-score
# 0                134         15552035      0.000689  457.038219
# 1                134         15552035      0.002886  204.690421
# 18               134         15552035      0.003446  102.144016
# 16               134         15552035      0.004334   91.074051
# 17               134         15552035      0.013846   50.872273
# 9                134         15552035      0.043460   33.369288
# 12               134         15552035      0.046304   32.315293
# 6                134         15552035      0.080346   27.939780
# 8                134         15552035      0.078123   24.764711
# 11               134         15552035      0.084129   23.843731
# 3                134         15552035      0.154748   22.485279
# 10               134         15552035      0.121084   19.768636
# 14               134         15552035      0.089945   19.706219
# 15               134         15552035      0.092900   19.380539
# 4                134         15552035      0.165259   19.272654
# 5                134         15552035      0.193202   17.760996
# 2                134         15552035      0.361089   16.040604
# 7                134         15552035      0.292340   14.255361
# 13               134         15552035      0.207401   12.719428

# %% [markdown]
# ### By the 2000s, "mouse" is more commonly found with "mickey," "computer," and "click."

# %%
collocationTable.sort_values(by='Z-score', ascending=False)[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 2              mickey       mouse            25                     282
# 63           antibody       mouse             7                      46
# 30         antibodies       mouse            10                     114
# 11               mice       mouse            15                     317
# 42             clicks       mouse             8                     165
# 12              click       mouse            14                     564
# 3                 cat       mouse            24                    1876
# 4               cells       mouse            20                    1488
# 44           keyboard       mouse             8                     241
# 57            desktop       mouse             7                     219
# 48            clicked       mouse             7                     301
# 64             disney       mouse             7                     414
# 7            computer       mouse            17                    3001
# 60               gene       mouse             7                     604
# 45             button       mouse             8                     928
# 71               stem       mouse             6                     562
# 54               tale       mouse             7                     907
# 29               hole       mouse            10                    1890
# 80              films       mouse             6                     944
# 0                like       mouse            51                   66617
# 35             screen       mouse             9                    2415
# 52         scientists       mouse             7                    1746
# 41             cancer       mouse             8                    2405
# 27              field       mouse            10                    4619
# 72               cell       mouse             6                    2354
# 23              front       mouse            11                    9820
# 28             trying       mouse            10                    8273
# 62            feeling       mouse             7                    4252
# 73               born       mouse             6                    3275
# 84             corner       mouse             6                    3379
#
#     Freq target word  Words in corpus  ExpectedFreq     Z-score
# 2                564         28132499      0.005654  332.415936
# 63               564         28132499      0.000922  230.476425
# 30               564         28132499      0.002285  209.128350
# 11               564         28132499      0.006355  188.079816
# 42               564         28132499      0.003308  139.037838
# 12               564         28132499      0.011307  131.553434
# 3                564         28132499      0.037610  123.560119
# 4                564         28132499      0.029831  115.623169
# 44               564         28132499      0.004832  115.022738
# 57               564         28132499      0.004391  105.576705
# 48               564         28132499      0.006034   90.033648
# 64               564         28132499      0.008300   76.744494
# 7                564         28132499      0.060164   69.062263
# 60               564         28132499      0.012109   63.502710
# 45               564         28132499      0.018605   58.515301
# 71               564         28132499      0.011267   56.419781
# 54               564         28132499      0.018184   51.776107
# 29               564         28132499      0.037891   51.178200
# 80               564         28132499      0.018925   43.476826
# 0                564         28132499      1.335537   42.975191
# 35               564         28132499      0.048416   40.682341
# 52               564         28132499      0.035004   37.227457
# 41               564         28132499      0.048215   36.213598
# 27               564         28132499      0.092602   32.557440
# 72               564         28132499      0.047193   27.402058
# 23               564         28132499      0.196871   24.347726
# 28               564         28132499      0.165857   24.147357
# 62               564         28132499      0.085244   23.683443
# 73               564         28132499      0.065657   23.159628
# 84               564         28132499      0.067742   22.792425

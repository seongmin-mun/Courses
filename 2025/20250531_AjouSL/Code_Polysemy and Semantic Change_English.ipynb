# %% [markdown]
# # Practice: Analyzing Polysemy and Semantic Change Using COHA Corpus
#
# ## Overview
# This practical session demonstrates how to analyze the polysemy of the word "mouse" over time using COHA (Corpus of Historical American English) data. Specifically, we will explore:
#
# 1. **Morphological Analysis**: Breaking sentences into morphemes and extracting meaningful context words.
# 2. **Window Collocations**: Calculating co-occurrence frequencies within a defined context window.
# 3. **Collocation Measures**: Using statistical metrics—Expected Frequency, MI, LL, Z-Score, and T-Score—to evaluate collocates.
# 4. **Semantic Change Detection**: Demonstrating the shift in the meaning of "mouse" from "animal" to "computer device" between the 1850s and 2000s.

# %% [markdown]
# ## Step 1: Data Preparation
# **Objective**: Ensure COHA data for the 1850s and 2000s is available and preprocess the data by splitting sentences into morphemes and filtering for content words.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
# Mount Google Drive to this Notebook instance.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# fileDir = "drive/My Drive/corpus/coha_2000s.txt"
fileDir = "drive/My Drive/corpus/coha_1850s.txt"
fr = open(fileDir, 'r', encoding='utf-8')
contents = fr.readlines()
fr.close()

textList = []
AllWordsList = []

num = 0
for content in contents:
    content = content.replace("\n", "")
    if num < 100:
        print(content)
    textList.append(content.lower())

    words = content.lower().strip().split(" ")
    for word in words:
        AllWordsList.append(word)
    num += 1
# Out:
# Sentence
# 184 poor and proud produced by charles keller
# html version by al haines
# poor and proud or the fortunes of katy redburn a story for young folks by oliver optic to alice marie adams this book is affectionately dedicated by her father
# poor and proud
# preface
# bobby bright and harry west whose histories were contained in the last two volumes of the library for young folks were both smart boys
# the author very grateful for the genial welcome extended to these young gentlemen begs leave to introduce to his juvenile friends a smart girl miss katy redburn whose fortunes he hopes will prove sufficiently interesting to secure their attention
# if any of my adult readers are disposed to accuse me of being a little extravagant i fear i shall have to let the case go by default but i shall plead in extenuation that i have tried to be reasonable even where a few grains of the romantic element were introduced for my shelf in boyhood and i may possibly have imbibed some of their peculiar spirit
# but i feel a lively satisfaction in the reflection that whatever exaggerations the critic may decide i have perpetrated in this volume i have made the success of katy redburn depend upon her good principles her politeness her determined perseverance and her overcoming that foolish pride which is a snare to the feet
# in these respects she is a worthy exemplar for the young
# pride and poverty do not seem to agree with each other but there is a pride which is not irreconcilable with the humblest station
# this pride of character finds an illustration in the life of my heroine
# thanking my young friends again for the pleasant reception given to my former books i submit this volume in the hope that katy redburn will prove to be a worthy and agreeable companion for their leisure hours
# william t adams
# dorchester sept
# 29 1858
# contents
# chapter
# i katy redburn and others are introduced ii
# the simon sneed visit the pawnbroker s shop iv
# katy matures a magnificent scheme v katy visits mrs
# gordon and gets rid of dr
# flynch vi
# katy prepares a stock of merchandise vii
# katy makes a large sale viii
# katy sells out and visits the mayor ix
# katy talks with the mayor and recovers the watch x katy in distress finds a champion xi
# katy meets with extraordinary success xii
# katy pays her debts and tommy goes to sea xiii
# katy employs an assistant xiv
# master simon sneed makes a mistake xv
# katy gets a letter from liverpool xvi
# ann grippen plays tricks upon travelers xvii
# the sun sets and the night comes on xviii
# katy struggles bravely through a series of trials xix
# katy resorts to a loan xx
# mrs
# gordon feels faint and katy enters a new sphere xxi
# katy goes to church and has a birthday party poor and proud or the fortunes of katy redburn
# chapter i katy redburn and johnny
# said a little girl of eleven dressed in coarse and ragged garments as she stooped down and looked into the basket of the dirty young fisherman who sat with his legs hanging over the edge of the pier
# i ll bet i wo nt replied johnny gruffly as he drew the basket out of the reach of the supplicant
# you need nt come round here tryin to hook my fish
# you hooked em said another juvenile angler who sat on the capsill of the pier by johnny s side
# who says i hooked em
# blustered johnny whose little dirty paws involuntarily assumed the form of a pair of fists scientifically disposed and ready to be the instruments of the owner s vengeance upon the traducer of his character
# i say so added tommy howard who did not seem to be at all alarmed at the warlike attitude of his fellowangler
# say it again and i up from his seat
# did nt you hear me
# once is enough
# tommy coolly hauled up a large flounder at that moment and threw the fish into his basket
# it was rather refreshing to see how regardless he was of that pair of menacing fists
# jest you say that once more and see what i ll do persisted johnny
# i wo nt do it
# you das nt say it again
# perhaps i das nt at any rate i sha nt
# do you mean to say i hooked them fish
# exclaimed johnny desperately for it seemed as though he must do something to vindicate his injured honor
# that s just what i did say
# but tommy was so confoundedly cool that his fellowangler had some doubts about the expediency of pitching into him
# probably a vision of defeat flashed through his excited brain and discretion seemed the better part of valor
# yet he was not or two toward his provoking companion a movement which to an unpracticed eye would indicate a purpose to do something
# do nt fight tommy said the little ragged girl
# i do nt mean to fight katy johnny at these words assumed an artistic attitude ready to strike the first blow only if johnny hits me i shall knock him into the middle of next week
# johnny did not strike
# he was a prudent young man
# do nt fight johnny repeated the girl turning to the excited aspirant for the honors of the ring
# do you suppose i ll let him tell me i hooked them fish
# blustered johnny
# he did nt mean anything
# yes i did interposed tommy
# he caught em on a hook so of course he hooked em
# i hooked mine too
# is that what you meant
# and his fists suddenly expanding into dirty paws again
# that s just what i meant and your skull is as thick as a twoinch plank or you would have seen what i meant
# i see now
# johnny was not disposed to resent this last insinuation about the solidity of his cranium
# he was evidently too glad to get out of the scrape without a broken head or a bloody nose
# johnny was a bully and he had a bully s reputation to maintain but he never fought when the odds were against him and he had a congressman s skill in backing out before the water got too hot
# on the whole he rather enjoyed the pun and he had the condescension to laugh heartily though somewhat unnaturally at the jest
# will you give me a flounder tommy
# said the little ragged girl as she glanced into his wellfilled basket
# what do you want of him katy
# asked tommy turning
# katy hesitated her bosom heaved and her lips compressed as though she feared to answer the question
# to eat she replied at last in a husky tone
# what s the matter katy
# the face of the child seemed to wear a load of care and anxiety and as the young fisherman gazed a tear started from her eye and slid down her cheek
# tommy s heart melted as he saw this exhibition of sorrow
# he wondered what could ail her
# my mother is sick replied katy dashing away the telltale tear
# i know that but what do you want of flounders
# we have nothing to eat now said katy bursting into tears
# mother has not been able to do any work for more than three months and we have nt got any money now
# it s all gone
# i have nt had any breakfast today
# take em all seat on the capsill of the pier
# how will you carry them

# %% [markdown]
# ### Extract sentences that contain the word "mouse."

# %%
targetWord = "mouse"

# %%
wordsInCorpus = 0
mouseText = []
AllText = ""
for each in textList:
    words = each.split(" ")
    for word in words:
        wordsInCorpus += 1

    if " " + targetWord + " " in each:
        mouseText.append(each)
        AllText = AllText + " " + each

AllText = AllText.strip()
print(wordsInCorpus)
print(len(AllWordsList))
# Out:
# 15552035
# 15552035

# %% [markdown]
# ### Check the concordance table for sentences containing "mouse."

# %%
from nltk import *
retokenize = RegexpTokenizer("[\w]+")
text = Text(retokenize.tokenize(AllText))
text.concordance(targetWord)
# Out:
# Displaying 25 of 109 matches:
#                            ketched a mouse hev ye that ai nt a mouse said andy
#  ketched a mouse hev ye that ai nt a mouse said andy as captain lemuel gulliver
# the world whose size was just that a mouse had just been caught in the trap and
# st and the door was locked and not a mouse to be heard and it s been just so si
# whale was but a species of magnified mouse or at least waterrat requiring only
# er to kill and boil from the crushed mouse 1851 i bear the trouble in my heart
# nceived in its crevice caught a tiny mouse lay pressed and lifeless who mid the
# n and the oppress d and uncomplaints mouse find some oasis where the savory che
# ains and no can be near let s go and mouse round their stoppingplace a little b
#  for the most part was as still as a mouse glanced round at these words one of
#  by her cousin i shall not said this mouse waste the time of i view it the sche
# ut doubt if indeed we could find any mouse who would do it a lion with the heat
# but whilst he dozed as he intended a mouse his royal back ascended nor thought
#  the trembling tiny brute but he the mouse with tearful eye implored the lion s
# ommenced a lordly roar when the poor mouse who heard the noise attended for she
#  at last forth issued he a lion by a mouse set free a plain but honest country
#  set free a plain but honest country mouse residing in a miller s house once on
# hey all arrived found where the city mouse had lived entered at midnight throug
# heir tedious track now said the city mouse i ll show what kind of fare i ve bro
# llish upon my word it is the country mouse replied all this must needs the poin
#  gigantic cats who spied our country mouse and brats a cunning mouse well up to
# ur country mouse and brats a cunning mouse well up to trap on pussy her two eye
# d clap illustration illustration the mouse and the weasel a very thin and hungr
# nd the weasel a very thin and hungry mouse into a granary stole where stood a b
# in in which was a small hole a young mouse of little experience thought to soft

# %% [markdown]
# ### Perform morphological analysis: Extract content words.

# %%
import nltk
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')

# Noun or Predicate
def tokenizerPOScontent(doc):
    stop_words = set(stopwords.words('english'))
    tagged_list = pos_tag(word_tokenize(doc))
    contentWords_list = [t[0] for t in tagged_list if "N" in t[1]  or "V" in t[1]]
    filtered_contentWords = [w for w in contentWords_list if not w.lower() in stop_words]
    length_contentWords = [w for w in filtered_contentWords if len(w) > 2]
    return length_contentWords

mousePOSText = []
for each in mouseText:
    print(" ".join(tokenizerPOScontent(each)))
    mousePOSText.append(" ".join(tokenizerPOScontent(each.strip())))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ketched mouse hev
# mouse said andy
# captain lemuel gulliver discovered island lilliput isaac know men world size mouse caught trap miller found
# went make bed breakfast door locked mouse heard since
# lost sense reverence marvels bulk ways anything like apprehension danger encountering opinion whale species mouse waterrat requiring circumvention application time trouble order kill boil
# crushed mouse bear trouble heart hath extinguished life sin malice preconceived
# crevice caught mouse lay pressed lifeless
# mid wonders age seen water moving thought darting zone crowns fall anointed brows time world history seals turn oppress uncomplaints mouse find oasis savory swell like mountains near
# let mouse round stoppingplace bart
# elizabeth part mouse glanced round words secondings anything said cousin
# said mouse waste time view scheme succeed without doubt find mouse
# lion heat oppress day composed rest whilst dozed intended mouse royal ascended thought harm esop tells mistaking something travelled round left found tremble hear tried explore monarch ear
# saying prepared foot crush trembling brute mouse eye implored lion clemency thought give prisner reprieve
# rage stamp tore commenced roar mouse heard noise attended knew voice
# lion strength effect length labor applied teeth network divide forth issued lion mouse set
# plain country mouse residing miller house time invited acquaintance town brought dainties doubt
# jogg talking things town arrived found city mouse lived entered midnight crack rested track
# said city mouse show kind fare brought led mice larder snug shelf nook embellish
# upon word country mouse replied needs point decide
# tribe servants cats spied country mouse brats
# cunning mouse trap eyes clap
# illustration illustration mouse weasel
# mouse stole stood basket grain hole
# mouse experience thought soften cat besought clemency asking life expense
# said mouse een rat charge house starve host
# mouse nothing seen caught said listen started frolic venture animals appeared eyes filled surprise
# cock mouse made mother picture describing like enthusiast
# child said mother cat enemy mouse rat
# mulhawl sat leaning chair surveying room aforesaid rattlesnakes escaped mouse face compound
# repeated howards minadab kneehigh mouse fetch along bag meal
# said kate behind coffeecup power transformation saw mouse run
# insult talk way keep church mouse time
# went afternoon play watch things cat mouse went within shooting distance sing dont mine
# workboxes gold thimbles bodkins scissors crimson velvet cases snakes squirmed make hop table get way looking boxes containing spry mouse jumped face raised lid music boxes place pillows drank cup tea vinaigrettes hold nose keep fainting saw dandy
# place lady room box ears call maid anything mouse woman
# neeze says advise examination valuables belonging night mouse stirs
# thisbe lifted mistress arms tugged room operation reminded mountain laboring bring mouse mouse laboring bring mountain
# surprised herald blows summons tremont astor middlesex house see come creeping piazza inhabitants mouse slinks hole pavement
# man species animals neighbors nothing mouse filled crevice
# lay wanderer ventured near house week fortnight time lived meadow mouse cattle poultry said survived time buried drifts without food like settler family town covered snow found hole chimney breath made drift relieved family
# returned drifts formed floundered wind road rabbit track print type meadow mouse seen
# mouse allowed pine tree dinner gnawing round order thin trees grow
# partington aknitting occupied grate heard patter matter rat mouse within closet door thieving rat mouse within closet door nothing
# works within house passed hour gloom behind wainscot crawled mouse bat room heard called tomb
# met cloisters corridors stone staircase eye looked casements owl screeched murderers mouse budged dull resounding footsteps
# gentleman morning discovered mouse bedchamber
# mouse rat held dread idea getting hand accident gave tremor
# offer fix flint mouse age patent matches
# blow directed mouse escaped corner
# blow resulted manner mouse finding beneath antique bureau gentleman compelled exert generalship bring
# vitus selected member favor regardless rest spasmodic kick fell mouse secreted
# partington relapsed beneath folds blankets eye towards realm dreams holding tenure upon world reality ear saluted mouse beneath chamber window mouse gnawing chamber carpet
# dreads detests mouse vague idea rats mice made regard torment
# point patience gave conquering dread arose opened door room led corridor taking light hand shoe made circuit room nook cranny mouse ensconse
# satisfying mouse left room closed door deposited upon hearth sought repose
# groan arose seizing lamp opened door satisfaction hear mouse drop step step reached floor
# mouse attempt run upon success
# though glad result sigh necessity impelled violence mouse continued blessing society moved
# mouse trouble mrs
# saying nothing wind chimney mouse crossing floor cricket made chirp
# one homer flaccus mastodon mouse tail comet pig
# night street street hurries like startled mouse phantom laughs mingling sleet man sits within house
# days pomp gone feet danced secure mouse bare walls hung drapery tell haunted halls scenes birth revelry wails resounded walls none hours pain joy gone love thee aldrich thomas bailey highland mary
# mouse ran settee without attracting notice dew eyes wandered rods stairway lock door without observing arms warriors motion cromwell brow assuming darker frown lips royal victim scaffold moving prayer panting buck shaking antlers defiance opening closing gills perceived gazer
# spare seem spare victim sort levity ways since see play cat mouse indulge liberty captive moment
# mouse gnawing wainscot near caused start look looking cross sins world hung image divine face
# purred frolicked pounced mouse caught tossed air went manoeuvres grimalkin
# seen nothing live demure church mouse manmonster nothing universe morning till night wait upon contribute gratification keeps home like bird cage look admire
# ripped seams beheld surprise minute beast mouse without vestige hair except tip tail crawl inches reposed fatigue
# mouse
# mouse though made hole house nothing world fill lad remained schooldays accomplished vision lads
# bait mouse rat trap draw rat mouse liberty cage
# risk life done crept cowardice dared sir confront man hear extent charge found position hovering around camp outlaws object mine concert nay striving laughs efforts powers done tell done gentlemen tell woman resolved justice strengthened purposing nothing made cause love mouse gnawed nets lion travis daughter tell knife outlaw throat effort rescue ladies bullet shot arm sirs gentlemen let peace believe connected believe moment lose agony death life death depend upon speed freedom moment
# figure scarce height venus rounded infant shown advantage morningdress buff muslin fluttered front display skirt mouse slipper
# chases rat mouse cockroach particle dust scrap litter
# love eyes margery quart sack stands chance ephraim nose gets scent mug mouse among dozen cats
# invested building venn mouse attempted run seen captured sound broken silence met sight
# came conclusion government set treasury caught mouse minister
# plays like cousincats plaguing mouse going devour
# knows parties made mouse pasties dessert serpents
# leaves lilac mouse ear borrow comparison indians
# tabby opened eyes erected smellers finding wind mouse made noise stretched paw yawned cuddled head show throat went sleep
# linger book murmured handing volume julia spoke prying peeping thing manuscript linger come end cat play mouse toying fruitage hangs way dallying love tasting forbearing evidence flavor appreciation
# mouse come sit table card dropped
# among animals domesticated horse mouse disposition change color form known taken place rat persia although europe short years thence imported america period associate pest man asia without undergoing change since dispersion europe preserved color type appears take view animals associates man difference respect changes granting means follows matter course domestication produces known changes hence taken granted animals analogues man regard changes
# evening sat rushbottomed rickety chair threading holding wound skeins silk yarn thought equator evening discoursed archrebel napoleon torn finders said got hands though day set mouse stolen morsel cheese toby toby matters
# death began play cat plays mouse succeeded making preyholding claws time drawing darting upon panther
# ham hamilton therefore propriety talk correlation cat mouse lion kid nuder distribution
# cock show prefers barleycorn gem cat transformed princess resume shape sees mouse cinderella wear glass slipper
# half humanity play adorers pretty tortoiseshell cat mouse enjoying agitation captive
# clap slice beefsteak mouse take swellin
# weather approaches hives entrances closed mouse gain admission
# bones species hare rabbit waterrat mouse fragments skeletons ravens pigeons larks ducks imbedded remains
# period deer dolphin walrus lamantin megalonyx megatherium glyptodon hyena weasel hare rabbit water rat mouse dasyurus halmaturus kangaroo kangaroo rat
# deer species mouse deer
# mouse deer lives berries fruits seldom found herbage upon examination paunch
# quadrupeds newera ellia highlands confined classes elk deer mouse deer hare otter jackal civet cat mongoose others varieties species squirrel squirrel wanderoo monkey species ceylon porcupine variety rat
# resistance slowgoing ant mouse cat encounter enemy added ant furnished sting addition pair mandibles
# chapter experiences freedom striped pig ben country mouse cars like beauties england land apples hotel inkstand exiled eyes crowd
# hawk tidy forms thought mouse means look create alarm
# brought stump set near ring without notice became mouse peeped sported kept eyes others forget keep eye toward sky ear direction
# part mouse pembina rivers among streams middle flows wooded shayenne valley possesses soil offers inducements settlement towards south jacques sioux vermillion head waters
# plateau bois des sioux mouse river valley territory minnesota
# mouse river valley portion minnesota ten twenty miles separated missouri river coteau missouri hundred feet level valley missouri

# %% [markdown]
# ## Step 2: Extract Context Words
# **Objective**: Use a window collocations to identify collocations of "mouse" in the corpora.

# %% [markdown]
# ### Apply window collocations to calculate co-occurrence frequencies and individual word frequencies.

# %%
wordType = set()
for each in mousePOSText:
    eachSplit = each.split(" ")
    for word in eachSplit:
        if word != targetWord:
            wordType.add(word)

wordList = list(wordType)

print(wordList[0:10])
print(len(wordType))
# Out:
# ['left', 'hear', 'lock', 'size', 'harm', 'rickety', 'horse', 'jogg', 'tremont', 'hand']
# 1005

# %% [markdown]
# ### Calculate co-occurrence frequencies and filter words top 30.

# %%
wordFreqDict = {}
for each in wordList:
    wordFreqDict[each] = 0

for each in mousePOSText:
    eachSplit = each.split(" ")
    for word in eachSplit:
        if word != targetWord:
            wordFreqDict[word] = wordFreqDict.get(word) + 1

wordFreqDicSorted = dict(sorted(wordFreqDict.items(), key=lambda x: x[1], reverse=True))

CoOccurringWords = []
collocations = []
topNum = 0
for key, value in wordFreqDicSorted.items():
  if topNum < 30:
    CoOccurringWords.append(key)
    collocations.append(value)
    # print(key, value)
  topNum += 1


# for key, value in wordFreqDicSorted.items():
#     if value > 5:
#         CoOccurringWords.append(key)
#         collocations.append(value)
print(len(CoOccurringWords))
print(CoOccurringWords[0:10])
print(collocations[0:10])
# Out:
# 30
# ['rat', 'cat', 'said', 'made', 'nothing', 'like', 'upon', 'time', 'room', 'house']
# [12, 11, 10, 9, 8, 8, 8, 8, 7, 7]

# %% [markdown]
# ### Calculate individual frequencies of co-occurring words.

# %%
CoOccurringWordsFreqDict = {}
for each in CoOccurringWords:
    CoOccurringWordsFreqDict[each] = AllWordsList.count(each)
    print(each, AllWordsList.count(each))
# Out:
# rat 80
# cat 335
# said 41908
# made 17960
# nothing 9325
# like 19180
# upon 33929
# time 22423
# room 5374
# house 9067
# door 5044
# without 14053
# eyes 9764
# species 1607
# lion 400
# thought 10782
# found 10439
# man 24071
# deer 503
# animals 988
# went 6752
# within 5612
# world 9394
# play 1484
# caught 1197
# seen 7133
# eye 4590
# heard 6349
# hole 431
# country 9279

# %%
freqCoWord = []
freqTargetWord = []
targetword = []
wordsInCorpusList = []
targetwordCount = AllWordsList.count(targetWord)

for key, value in CoOccurringWordsFreqDict.items():
    freqCoWord.append(value)
    freqTargetWord.append(targetwordCount)
    targetword.append(targetWord)
    wordsInCorpusList.append(wordsInCorpus)

print(freqCoWord[0:10])
# Out:
# [80, 335, 41908, 17960, 9325, 19180, 33929, 22423, 5374, 9067]

# %% [markdown]
# ### Generate the final dataset.

# %%
import pandas as pd
collocationTable = pd.DataFrame({'Co-occurring words':CoOccurringWords,'Target word':targetword,'Collocations':collocations,'Freq co-occurring word':freqCoWord,'Freq target word':freqTargetWord,'Words in corpus':wordsInCorpusList})
print(collocationTable)
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 0                 rat       mouse            12                      80
# 1                 cat       mouse            11                     335
# 2                said       mouse            10                   41908
# 3                made       mouse             9                   17960
# 4             nothing       mouse             8                    9325
# 5                like       mouse             8                   19180
# 6                upon       mouse             8                   33929
# 7                time       mouse             8                   22423
# 8                room       mouse             7                    5374
# 9               house       mouse             7                    9067
# 10               door       mouse             7                    5044
# 11            without       mouse             7                   14053
# 12               eyes       mouse             7                    9764
# 13            species       mouse             6                    1607
# 14               lion       mouse             6                     400
# 15            thought       mouse             6                   10782
# 16              found       mouse             6                   10439
# 17                man       mouse             6                   24071
# 18               deer       mouse             6                     503
# 19            animals       mouse             5                     988
# 20               went       mouse             5                    6752
# 21             within       mouse             5                    5612
# 22              world       mouse             5                    9394
# 23               play       mouse             5                    1484
# 24             caught       mouse             5                    1197
# 25               seen       mouse             5                    7133
# 26                eye       mouse             4                    4590
# 27              heard       mouse             4                    6349
# 28               hole       mouse             4                     431
# 29            country       mouse             4                    9279
#
#     Freq target word  Words in corpus
# 0                134         15552035
# 1                134         15552035
# 2                134         15552035
# 3                134         15552035
# 4                134         15552035
# 5                134         15552035
# 6                134         15552035
# 7                134         15552035
# 8                134         15552035
# 9                134         15552035
# 10               134         15552035
# 11               134         15552035
# 12               134         15552035
# 13               134         15552035
# 14               134         15552035
# 15               134         15552035
# 16               134         15552035
# 17               134         15552035
# 18               134         15552035
# 19               134         15552035
# 20               134         15552035
# 21               134         15552035
# 22               134         15552035
# 23               134         15552035
# 24               134         15552035
# 25               134         15552035
# 26               134         15552035
# 27               134         15552035
# 28               134         15552035
# 29               134         15552035

# %%
collocationTable[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 0                 rat       mouse            12                      80
# 1                 cat       mouse            11                     335
# 2                said       mouse            10                   41908
# 3                made       mouse             9                   17960
# 4             nothing       mouse             8                    9325
# 5                like       mouse             8                   19180
# 6                upon       mouse             8                   33929
# 7                time       mouse             8                   22423
# 8                room       mouse             7                    5374
# 9               house       mouse             7                    9067
# 10               door       mouse             7                    5044
# 11            without       mouse             7                   14053
# 12               eyes       mouse             7                    9764
# 13            species       mouse             6                    1607
# 14               lion       mouse             6                     400
# 15            thought       mouse             6                   10782
# 16              found       mouse             6                   10439
# 17                man       mouse             6                   24071
# 18               deer       mouse             6                     503
# 19            animals       mouse             5                     988
# 20               went       mouse             5                    6752
# 21             within       mouse             5                    5612
# 22              world       mouse             5                    9394
# 23               play       mouse             5                    1484
# 24             caught       mouse             5                    1197
# 25               seen       mouse             5                    7133
# 26                eye       mouse             4                    4590
# 27              heard       mouse             4                    6349
# 28               hole       mouse             4                     431
# 29            country       mouse             4                    9279
#
#     Freq target word  Words in corpus
# 0                134         15552035
# 1                134         15552035
# 2                134         15552035
# 3                134         15552035
# 4                134         15552035
# 5                134         15552035
# 6                134         15552035
# 7                134         15552035
# 8                134         15552035
# 9                134         15552035
# 10               134         15552035
# 11               134         15552035
# 12               134         15552035
# 13               134         15552035
# 14               134         15552035
# 15               134         15552035
# 16               134         15552035
# 17               134         15552035
# 18               134         15552035
# 19               134         15552035
# 20               134         15552035
# 21               134         15552035
# 22               134         15552035
# 23               134         15552035
# 24               134         15552035
# 25               134         15552035
# 26               134         15552035
# 27               134         15552035
# 28               134         15552035
# 29               134         15552035

# %% [markdown]
# ## Step 3: Collocation measures
# **Objective**: Apply the learned collocation measures to the dataset.

# %% [markdown]
# ### Expected Frequency
# The formula for Expected Frequency is:
#
# $$E = \frac{f(w_1) \cdot f(w_2)}{N}$$
#
# Where:
# - $f(w_1)$: Frequency of the target word.
# - $f(w_2)$: Frequency of the co-occurring word.
# - $N$: Total number of tokens in the corpus.

# %%
collocationTable['ExpectedFreq'] = (collocationTable['Freq co-occurring word']*collocationTable['Freq target word'])/collocationTable['Words in corpus']
collocationTable.sort_values(by='ExpectedFreq', ascending=False)[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 2                said       mouse            10                   41908
# 6                upon       mouse             8                   33929
# 17                man       mouse             6                   24071
# 7                time       mouse             8                   22423
# 5                like       mouse             8                   19180
# 3                made       mouse             9                   17960
# 11            without       mouse             7                   14053
# 15            thought       mouse             6                   10782
# 16              found       mouse             6                   10439
# 12               eyes       mouse             7                    9764
# 22              world       mouse             5                    9394
# 4             nothing       mouse             8                    9325
# 29            country       mouse             4                    9279
# 9               house       mouse             7                    9067
# 25               seen       mouse             5                    7133
# 20               went       mouse             5                    6752
# 27              heard       mouse             4                    6349
# 21             within       mouse             5                    5612
# 8                room       mouse             7                    5374
# 10               door       mouse             7                    5044
# 26                eye       mouse             4                    4590
# 13            species       mouse             6                    1607
# 23               play       mouse             5                    1484
# 24             caught       mouse             5                    1197
# 19            animals       mouse             5                     988
# 18               deer       mouse             6                     503
# 28               hole       mouse             4                     431
# 14               lion       mouse             6                     400
# 1                 cat       mouse            11                     335
# 0                 rat       mouse            12                      80
#
#     Freq target word  Words in corpus  ExpectedFreq
# 2                134         15552035      0.361089
# 6                134         15552035      0.292340
# 17               134         15552035      0.207401
# 7                134         15552035      0.193202
# 5                134         15552035      0.165259
# 3                134         15552035      0.154748
# 11               134         15552035      0.121084
# 15               134         15552035      0.092900
# 16               134         15552035      0.089945
# 12               134         15552035      0.084129
# 22               134         15552035      0.080941
# 4                134         15552035      0.080346
# 29               134         15552035      0.079950
# 9                134         15552035      0.078123
# 25               134         15552035      0.061460
# 20               134         15552035      0.058177
# 27               134         15552035      0.054704
# 21               134         15552035      0.048354
# 8                134         15552035      0.046304
# 10               134         15552035      0.043460
# 26               134         15552035      0.039549
# 13               134         15552035      0.013846
# 23               134         15552035      0.012786
# 24               134         15552035      0.010314
# 19               134         15552035      0.008513
# 18               134         15552035      0.004334
# 28               134         15552035      0.003714
# 14               134         15552035      0.003446
# 1                134         15552035      0.002886
# 0                134         15552035      0.000689

# %% [markdown]
# ### Z-Score
# The formula for Z-Score is:
#
# $$Z = \frac{f(w_1, w_2) - E}{\sqrt{E}}$$
#
# Where:
# - $f(w_1, w_2)$: Observed frequency of the collocation.
# - $E$: Expected frequency.

# %%
import numpy as np
collocationTable['Z-score'] = (collocationTable['Collocations'] - collocationTable['ExpectedFreq'])/np.sqrt(collocationTable['ExpectedFreq'])
collocationTable.sort_values(by='Z-score', ascending=False)[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 0                 rat       mouse            12                      80
# 1                 cat       mouse            11                     335
# 14               lion       mouse             6                     400
# 18               deer       mouse             6                     503
# 28               hole       mouse             4                     431
# 19            animals       mouse             5                     988
# 13            species       mouse             6                    1607
# 24             caught       mouse             5                    1197
# 23               play       mouse             5                    1484
# 10               door       mouse             7                    5044
# 8                room       mouse             7                    5374
# 4             nothing       mouse             8                    9325
# 9               house       mouse             7                    9067
# 12               eyes       mouse             7                    9764
# 21             within       mouse             5                    5612
# 3                made       mouse             9                   17960
# 20               went       mouse             5                    6752
# 25               seen       mouse             5                    7133
# 26                eye       mouse             4                    4590
# 11            without       mouse             7                   14053
# 16              found       mouse             6                   10439
# 15            thought       mouse             6                   10782
# 5                like       mouse             8                   19180
# 7                time       mouse             8                   22423
# 22              world       mouse             5                    9394
# 27              heard       mouse             4                    6349
# 2                said       mouse            10                   41908
# 6                upon       mouse             8                   33929
# 29            country       mouse             4                    9279
# 17                man       mouse             6                   24071
#
#     Freq target word  Words in corpus  ExpectedFreq     Z-score
# 0                134         15552035      0.000689  457.038219
# 1                134         15552035      0.002886  204.690421
# 14               134         15552035      0.003446  102.144016
# 18               134         15552035      0.004334   91.074051
# 28               134         15552035      0.003714   65.578153
# 19               134         15552035      0.008513   54.099431
# 13               134         15552035      0.013846   50.872273
# 24               134         15552035      0.010314   49.132333
# 23               134         15552035      0.012786   44.104431
# 10               134         15552035      0.043460   33.369288
# 8                134         15552035      0.046304   32.315293
# 4                134         15552035      0.080346   27.939780
# 9                134         15552035      0.078123   24.764711
# 12               134         15552035      0.084129   23.843731
# 21               134         15552035      0.048354   22.518110
# 3                134         15552035      0.154748   22.485279
# 20               134         15552035      0.058177   20.488596
# 25               134         15552035      0.061460   19.920659
# 26               134         15552035      0.039549   19.914966
# 11               134         15552035      0.121084   19.768636
# 16               134         15552035      0.089945   19.706219
# 15               134         15552035      0.092900   19.380539
# 5                134         15552035      0.165259   19.272654
# 7                134         15552035      0.193202   17.760996
# 22               134         15552035      0.080941   17.290119
# 27               134         15552035      0.054704   16.868175
# 2                134         15552035      0.361089   16.040604
# 6                134         15552035      0.292340   14.255361
# 29               134         15552035      0.079950   13.863798
# 17               134         15552035      0.207401   12.719428

# %% [markdown]
# ## Step 4: Demonstrating Semantic Change
# **Objective**: Create tables showing the shift in collocates between the 1850s and 2000s.

# %% [markdown]
# ### In the 1850s, "mouse" is associated with collocates like "rat," "house," and "animals"!

# %%
collocationTable.sort_values(by='Z-score', ascending=False)[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 0                 rat       mouse            12                      80
# 1                 cat       mouse            11                     335
# 14               lion       mouse             6                     400
# 18               deer       mouse             6                     503
# 28               hole       mouse             4                     431
# 19            animals       mouse             5                     988
# 13            species       mouse             6                    1607
# 24             caught       mouse             5                    1197
# 23               play       mouse             5                    1484
# 10               door       mouse             7                    5044
# 8                room       mouse             7                    5374
# 4             nothing       mouse             8                    9325
# 9               house       mouse             7                    9067
# 12               eyes       mouse             7                    9764
# 21             within       mouse             5                    5612
# 3                made       mouse             9                   17960
# 20               went       mouse             5                    6752
# 25               seen       mouse             5                    7133
# 26                eye       mouse             4                    4590
# 11            without       mouse             7                   14053
# 16              found       mouse             6                   10439
# 15            thought       mouse             6                   10782
# 5                like       mouse             8                   19180
# 7                time       mouse             8                   22423
# 22              world       mouse             5                    9394
# 27              heard       mouse             4                    6349
# 2                said       mouse            10                   41908
# 6                upon       mouse             8                   33929
# 29            country       mouse             4                    9279
# 17                man       mouse             6                   24071
#
#     Freq target word  Words in corpus  ExpectedFreq     Z-score
# 0                134         15552035      0.000689  457.038219
# 1                134         15552035      0.002886  204.690421
# 14               134         15552035      0.003446  102.144016
# 18               134         15552035      0.004334   91.074051
# 28               134         15552035      0.003714   65.578153
# 19               134         15552035      0.008513   54.099431
# 13               134         15552035      0.013846   50.872273
# 24               134         15552035      0.010314   49.132333
# 23               134         15552035      0.012786   44.104431
# 10               134         15552035      0.043460   33.369288
# 8                134         15552035      0.046304   32.315293
# 4                134         15552035      0.080346   27.939780
# 9                134         15552035      0.078123   24.764711
# 12               134         15552035      0.084129   23.843731
# 21               134         15552035      0.048354   22.518110
# 3                134         15552035      0.154748   22.485279
# 20               134         15552035      0.058177   20.488596
# 25               134         15552035      0.061460   19.920659
# 26               134         15552035      0.039549   19.914966
# 11               134         15552035      0.121084   19.768636
# 16               134         15552035      0.089945   19.706219
# 15               134         15552035      0.092900   19.380539
# 5                134         15552035      0.165259   19.272654
# 7                134         15552035      0.193202   17.760996
# 22               134         15552035      0.080941   17.290119
# 27               134         15552035      0.054704   16.868175
# 2                134         15552035      0.361089   16.040604
# 6                134         15552035      0.292340   14.255361
# 29               134         15552035      0.079950   13.863798
# 17               134         15552035      0.207401   12.719428

# %% [markdown]
# ### By the 2000s, "mouse" is more commonly found with "mickey," "computer," and "click."

# %%
collocationTable.sort_values(by='Z-score', ascending=False)[0:30]
# Out:
#    Co-occurring words Target word  Collocations  Freq co-occurring word  \
# 1              mickey       mouse            25                     282
# 28         antibodies       mouse            10                     114
# 9                mice       mouse            15                     317
# 12              click       mouse            14                     564
# 3                 cat       mouse            24                    1876
# 4               cells       mouse            20                    1488
# 7            computer       mouse            17                    3001
# 0                like       mouse            51                   66617
# 27              field       mouse            10                    4619
# 17              front       mouse            11                    9820
# 6                 see       mouse            18                   30031
# 13              house       mouse            13                   17781
# 25               used       mouse            10                   11202
# 14             mother       mouse            12                   17251
# 11                man       mouse            15                   27737
# 22               hand       mouse            11                   15580
# 5                time       mouse            19                   46556
# 26                put       mouse            10                   13807
# 10              years       mouse            15                   30281
# 8                 get       mouse            16                   35091
# 2                said       mouse            25                   82556
# 18               work       mouse            11                   19069
# 29             looked       mouse            10                   16567
# 16             around       mouse            12                   24755
# 20                day       mouse            11                   23424
# 23               made       mouse            11                   23898
# 19               make       mouse            11                   24359
# 15                way       mouse            12                   30753
# 24             people       mouse            11                   33115
# 21               know       mouse            11                   34855
#
#     Freq target word  Words in corpus  ExpectedFreq     Z-score
# 1                564         28132499      0.005654  332.415936
# 28               564         28132499      0.002285  209.128350
# 9                564         28132499      0.006355  188.079816
# 12               564         28132499      0.011307  131.553434
# 3                564         28132499      0.037610  123.560119
# 4                564         28132499      0.029831  115.623169
# 7                564         28132499      0.060164   69.062263
# 0                564         28132499      1.335537   42.975191
# 27               564         28132499      0.092602   32.557440
# 17               564         28132499      0.196871   24.347726
# 6                564         28132499      0.602061   22.422163
# 13               564         28132499      0.356473   21.176527
# 25               564         28132499      0.224578   20.627774
# 14               564         28132499      0.345848   19.817011
# 11               564         28132499      0.556071   19.369580
# 22               564         28132499      0.312348   19.123316
# 5                564         28132499      0.933354   18.700547
# 26               564         28132499      0.276803   18.480940
# 10               564         28132499      0.607073   18.472625
# 8                564         28132499      0.703504   18.237222
# 2                564         28132499      1.655082   18.146072
# 18               564         28132499      0.382295   17.172412
# 29               564         28132499      0.332135   16.775414
# 16               564         28132499      0.496288   16.329434
# 20               564         28132499      0.469604   15.366635
# 23               564         28132499      0.479107   15.199750
# 19               564         28132499      0.488349   15.042008
# 15               564         28132499      0.616536   14.497573
# 24               564         28132499      0.663889   12.685552
# 21               564         28132499      0.698773   12.323130
